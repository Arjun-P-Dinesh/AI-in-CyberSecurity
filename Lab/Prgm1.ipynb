# %%
# !pip install watermark
# Out:
# Collecting watermark
#   Downloading watermark-2.4.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython>=6.0 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from watermark) (8.21.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from watermark) (7.0.1)
# Requirement already satisfied: setuptools in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from watermark) (68.2.2)
# Requirement already satisfied: zipp>=0.5 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from importlib-metadata>=1.4->watermark) (3.17.0)
# Requirement already satisfied: decorator in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (2.17.2)
# Requirement already satisfied: stack-data in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (5.14.1)
# Requirement already satisfied: pexpect>4.3 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from ipython>=6.0->watermark) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.0->watermark) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.0->watermark) (0.7.0)
# Requirement already satisfied: wcwidth in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.0->watermark) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from stack-data->ipython>=6.0->watermark) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from stack-data->ipython>=6.0->watermark) (2.4.1)
# Requirement already satisfied: pure-eval in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from stack-data->ipython>=6.0->watermark) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.0->watermark) (1.16.0)
# Downloading watermark-2.4.3-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: watermark
# Successfully installed watermark-2.4.3

# %%
# !pip install scikit-learn
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/scikit-learn/
# Collecting scikit-learn
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/cb/7a/7a0ac495181f4d27b06fe37c211950a8037f276691cc3e68b9cc25727a44/scikit_learn-1.4.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading scikit_learn-1.4.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/arj/anaconda3/envs/clg/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 290.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib>=1.2.0 in /home/arj/.local/lib/python3.12/site-packages (from scikit-learn) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 818.3 kB/s eta 0:00:0000:0100:01
# Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 2.3 MB/s eta 0:00:0000:0100:010m
# Downloading threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.4.1.post1 scipy-1.12.0 threadpoolctl-3.3.0

# %%
# %load_ext watermark
# %watermark -a "Alessandro Parisi" -u -d -v -p numpy,pandas,matplotlib,sklearn,seaborn
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Author: Alessandro Parisi
#
# Last updated: 2024-02-19
#
# Python implementation: CPython
# Python version       : 3.12.1
# IPython version      : 8.21.0
#
# numpy     : 1.26.3
# pandas    : 2.2.0
# matplotlib: 3.8.3
# sklearn   : 1.4.1.post1
# seaborn   : 0.13.2

# %%
# Execute plot() inline without calling show()
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('/home/arj/TriSem3/AI-in-CyberSecurity/Datasets/sms_spam_perceptron.csv')

y = df.iloc[:, 0].values
y = np.where(y == 'spam', -1, 1)

X = df.iloc[:, [1, 2]].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import Perceptron

p = Perceptron(max_iter=40, eta0=0.1, random_state=0)
p.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, max_iter=40)

# %%
y_pred = p.predict(X_test)

# %%
# Thanks to Sebastian Raschka for 'plot_decision_regions'
# https://github.com/rasbt/python-machine-learning-book
from defs import plot_decision_regions

X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X=X_combined, y=y_combined,
                      classifier=p, test_idx=range(-5, 5))
plt.xlabel('suspect words')
plt.ylabel('spam or ham')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-1.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=0'>1</a> # Thanks to Sebastian Raschka for 'plot_decision_regions'
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=1'>2</a> # https://github.com/rasbt/python-machine-learning-book
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=2'>3</a> from defs import plot_decision_regions
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=4'>5</a> X_combined = np.vstack((X_train, X_test))
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X10sdW50aXRsZWQ%3D?line=5'>6</a> y_combined = np.hstack((y_train, y_test))
#
# ModuleNotFoundError: No module named 'defs'

# %%
from sklearn.metrics import accuracy_score

print('Misclassified samples: %d' % (y_test != y_pred).sum())
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
